# %%
import nltk
# from nltk.corpus import stopwords
# from nltk.stem import PorterStemmer
# from nltk.stem import WordNetLemmatizer
import pandas as pd

# %%
import re

# Attempt to read the CSV file with automatic separator detection
with open('chat.txt', 'r', encoding='utf-8') as f:
    lines = f.readlines()
    #print(lines)

    # Remove text within square brackets
    cleaned_lines = [re.sub(r'\[.*?\]', '', line) for line in lines]
    #print(cleaned_lines)
    # Remove the text "Kipa: " from each line
    cleaned_lines = [line.replace('Kipa: ', '') for line in cleaned_lines]
    cleaned_lines = [line.replace('Jani Rytkönen: ', '') for line in cleaned_lines]
    cleaned_lines = [line.replace('Jussi: ', '') for line in cleaned_lines]
    print(cleaned_lines)
# Out:
# [' Kelatkaa kohta leffasta 30v. Tulee vanha olo\n', ' 🌹\n', ' se on kevät nyt!\n', '\u200e \u200etarraa ei sisällytetty\n', ' Niin taitaa olla\n', ' Mä olin nyt töissä sunnuntaina! Mitä jessekin nyt sanoo..\n', ' haiseeko hiki?\n', ' No minäkin niitä vähän järjestelyin kanssa. Show me the money 🤑\n', ' Oli kyllä hieno ilma tehdä ja olo varmaan hyvä. Mikä on arvo sana sunnuntain työpäivään\n', ' Tuli hiki 😰 ja haiseekin.\n', ' Oli kiva ilma\n', ' Perkele niin tulee yleinsä,haisin viime viikolla kuin sika. Pitää varmaan joku päivä kokeilla mistä toi suihku juttu on peräisin\n', ' Huomenta kalakaverit\n', ' Huomenta\n', ' huomenta!\n', ' Sijoitin kaurapuuroon. Musta tulee kaurapuuro-oligarkki.\n', ' 💰\n', ' Puolivitsinä. Oon ostellut pikkuhiljaa pitkään säilyviä ruokia varastoon. joita tulee muutenkin syötyä.\n', ' älä unohda 🧻\n', ' Hieno homma ei yhtään hullu. Kävin juuri ostaa asiakkaalle viikon ruuat. Kyllä sai taas vähän kaupassa seikkailla.🧐\n', ' Ruoka ei ainakaan tule halpenemaa
# ...

# %%
from wordcloud import WordCloud

import matplotlib.pyplot as plt

# Join all the lines into a single string
text = ' '.join(cleaned_lines)

# Create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = stopwords.words("finnish")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     U:\Users\jk026110\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Out:
# [' Kelatkaa kohta leffasta 30v. Tulee vanha olo\n', ' 🌹\n', ' se on kevät nyt!\n', '\u200e \u200etarraa ei sisällytetty\n', ' Niin taitaa olla\n', ' Mä olin nyt töissä sunnuntaina! Mitä jessekin nyt sanoo..\n', ' haiseeko hiki?\n', ' No minäkin niitä vähän järjestelyin kanssa. Show me the money 🤑\n', ' Oli kyllä hieno ilma tehdä ja olo varmaan hyvä. Mikä on arvo sana sunnuntain työpäivään\n', ' Tuli hiki 😰 ja haiseekin.\n', ' Oli kiva ilma\n', ' Perkele niin tulee yleinsä,haisin viime viikolla kuin sika. Pitää varmaan joku päivä kokeilla mistä toi suihku juttu on peräisin\n', ' Huomenta kalakaverit\n', ' Huomenta\n', ' huomenta!\n', ' Sijoitin kaurapuuroon. Musta tulee kaurapuuro-oligarkki.\n', ' 💰\n', ' Puolivitsinä. Oon ostellut pikkuhiljaa pitkään säilyviä ruokia varastoon. joita tulee muutenkin syötyä.\n', ' älä unohda 🧻\n', ' Hieno homma ei yhtään hullu. Kävin juuri ostaa asiakkaalle viikon ruuat. Kyllä sai taas vähän kaupassa seikkailla.🧐\n', ' Ruoka ei ainakaan tule halpenemaa
# ...

# %%
# Join all the lines into a single string
# Remove stop words from cleaned_lines
cleaned_lines = [' '.join([word for word in line.split() if word.lower() not in stop_words]) for line in cleaned_lines]

# Join all the lines into a single string
text = ' '.join(cleaned_lines)

# Create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
